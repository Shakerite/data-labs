# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
# import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
url='https://github.com/trending/developers'
response=requests.get(url).content
soup=BeautifulSoup(response,'lxml') 
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-a2fba223d5af91496cac70d4ec3624df.css" integrity="sha512-3+HOqCwtQal5hOJQ+mdxiq5zmGOTjF6RhjDsPLxbKDYgGlLFeCwzoIanb7j5IiCuXKUqyC2q8FdkC4nmx2P2rA==" media="all" rel="stylesheet"/>
# ...

# %%
# Out:
# ['microsoft(Microsoft)',
#  'jackfrued(骆昊)',
#  'jlevy(JoshuaLevy)',
#  'binhnguyennus(JohnGit)',
#  'jaywcjlove(小弟调调™)',
#  'apache(TheApacheSoftwareFoundation)',
#  'synox(AravindoWingeier)',
#  'alibaba(Alibaba)',
#  'google(Google)',
#  'MisterBooo(程序员吴师兄)',
#  'facebook(Facebook)',
#  'sghall(SteveHall)',
#  'smooth-code(SmoothCode)',
#  'anacoimbrag(AnaCoimbra)',
#  'sindresorhus(SindreSorhus)',
#  'seungeunrho',
#  'TheAlgorithms(TheAlgorithms)',
#  'afshinea(AfshineAmidi)',
#  'smallnest(smallnest)',
#  'vuejs(vuejs)',
#  'flutter(Flutter)',
#  'tensorflow',
#  'CyC2018',
#  'macrozheng(macro)',
#  'wangzheng0822']

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
lst= soup.find_all('h2', {'class':'f3 text-normal'})
lst2=["".join(x.text.strip().split())for x in lst]

lst2
# Out:
# ['microsoft(Microsoft)',
#  'jackfrued(骆昊)',
#  'jlevy(JoshuaLevy)',
#  'binhnguyennus(JohnGit)',
#  'jaywcjlove(小弟调调™)',
#  'apache(TheApacheSoftwareFoundation)',
#  'synox(AravindoWingeier)',
#  'alibaba(Alibaba)',
#  'google(Google)',
#  'MisterBooo(程序员吴师兄)',
#  'facebook(Facebook)',
#  'sghall(SteveHall)',
#  'smooth-code(SmoothCode)',
#  'anacoimbrag(AnaCoimbra)',
#  'sindresorhus(SindreSorhus)',
#  'seungeunrho',
#  'TheAlgorithms(TheAlgorithms)',
#  'afshinea(AfshineAmidi)',
#  'smallnest(smallnest)',
#  'vuejs(vuejs)',
#  'flutter(Flutter)',
#  'tensorflow',
#  'CyC2018',
#  'macrozheng(macro)',
#  'wangzheng0822']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
response=requests.get(url).content
soup=BeautifulSoup(response,'lxml') 
soup

lst= soup.find_all('h3')
lst2=["".join(x.text.strip().split()) for x in lst]
lst2
# Out:
# ['TheAlgorithms/Python',
#  'seungeunrho/minimalRL',
#  'apachecn/AiLearning',
#  'STVIR/pysot',
#  'ytdl-org/youtube-dl',
#  'vinta/awesome-python',
#  'tensorflow/models',
#  'facebookresearch/pythia',
#  'donnemartin/system-design-primer',
#  'ageitgey/face_recognition',
#  'shunliz/Machine-Learning',
#  'opencv/open_model_zoo',
#  'deepfakes/faceswap',
#  'thunlp/ERNIE',
#  'woj-ciech/LeakLooker',
#  'weskerfoot/DeleteFB',
#  '521xueweihan/HelloGitHub',
#  'toddmotto/public-apis',
#  'machinelearningmindset/machine-learning-course',
#  'keras-team/keras',
#  'zalando-incubator/kopf',
#  'home-assistant/home-assistant',
#  'django/django',
#  'OWASP/CheatSheetSeries',
#  'encode/django-rest-framework']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
response=requests.get(url).content
soup=BeautifulSoup(response,'lxml') 
soup
img= soup.find_all('img')
[x['src'] for x in img]
# Out:
# ['//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
response=requests.get(url).content
soup_python=BeautifulSoup(response,'lxml') 
soup_python
link= soup.find_all('a')
link
[x.get('href') for x in link]
# Out:
# [None,
#  '/wiki/Wikipedia:Featured_articles',
#  '/wiki/Wikipedia:Protection_policy#semi',
#  '#mw-head',
#  '#p-search',
#  '/wiki/The_Walt_Disney_Company',
#  '/wiki/Walt_Disney_(disambiguation)',
#  '/wiki/File:Walt_Disney_1946.JPG',
#  '/wiki/Chicago',
#  '/wiki/Burbank,_California',
#  '/wiki/The_Walt_Disney_Company',
#  '/wiki/Disney_family',
#  '/wiki/Academy_Awards',
#  '/wiki/Golden_Globe_Award',
#  '/wiki/Emmy_Award',
#  '/wiki/File:Walt_Disney_1942_signature.svg',
#  '/wiki/Help:IPA/English',
#  '#cite_note-OD:_pronunciation-1',
#  '/wiki/Modern_animation_in_the_United_States',
#  '/wiki/Cartoon',
#  '/wiki/Academy_Awards',
#  '/wiki/Golden_Globe_Awards',
#  '/wiki/Emmy_Award',
#  '/wiki/National_Film_Registry',
#  '/wiki/Library_of_Congress',
#  '/wiki/The_Walt_Disney_Company',
#  '/wiki/Roy_O._Disney',
#  '/wiki/Ub_Iwerks',
#  '/wiki/Mickey_Mouse',
#  '/wiki/Technicolor',
#  '/wiki/Feature-length',
#  '/wiki/Snow_White_and_the_Seven_Dwarfs_(1937_film)',
# ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
response=requests.get(url).content
soup_usc=BeautifulSoup(response,'lxml') 
soup_usc
usc= soup_usc.find_all('div', {'class':'usctitle'})
len(usc)
["".join(x.text.strip().split()) for x in usc]
# Out:
# 55

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
response=requests.get(url).content
soup_fbi=BeautifulSoup(response,'lxml') 
soup_fbi
fbi= soup_fbi.find_all('h3', {'class':'title'})
[" ".join(x.text.split()) for x in fbi]
# Out:
# ['ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ARNOLDO JIMENEZ',
#  'ALEJANDRO ROSALES CASTILLO',
#  'YASER ABDEL SAID',
#  'JASON DEREK BROWN',
#  'RAFAEL CARO-QUINTERO',
#  'ALEXIS FLORES',
#  'SANTIAGO VILLALBA MEDEROS',
#  'LAMONT STEPHENSON']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
response=requests.get(url).content
soup_eq=BeautifulSoup(response,'lxml') 
soup_eq
eq= soup_eq.find_all('tr')
eq[0]
#{'class':'title'})
#[" ".join(x.text.split()) for x in fbi]
# Out:
# <tr><td class="ban1" onclick="window.location.href='https://www.emsc-csem.org';" onmouseover="this.style.cursor='pointer';">
# <img alt="logo - home" src="https://static2.emsc.eu/Css/img/logo.png" style="width:150px;height:81px;"/></td>
# <td class="ban2 ban022" onclick="window.location.href='https://www.emsc-csem.org';" onmouseover="this.style.cursor='pointer';">
# <div style="border:0; position:relative; float:right; width:110px; height:80px; margin-top:-5px; margin-right:25px; ">
# <div id="androidstore" style="border:0; position:relative; float:left; width:110px; height:35px;"></div>
# <div id="iosstore" style="border:0; position:relative; float:left; width:110px; height:35px; margin-top:8px;"></div>
# </div>
# <script type="text/javascript">set_server_date(2019,5,28,15,12,29)</script>
# <div id="ejs_server_heure">Current time: 2019-05-28 15:12:29 UTC</div>
# </td>
# ...

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/search/anything/anywhere/anytime'

# %%
response=requests.get(url).content
soup_hack=BeautifulSoup(response,'html.parser') 
soup_hack
hack= soup_hack.find_all('div', {'class':'card-body'})
hack
# Out:
# [<div class="card-body"><div class="row"><div class="col-12 col-sm-5"><!--img(id=imgId).img-fluid--><img height="180px" src="https://storage.googleapis.com/hackevents-prod.appspot.com/hackathons%2Fimages%2FJmEhzggNQncdHShNN5kDNpj1YMw1%2FHiring%20Hackathon.png?GoogleAccessId=firebase-adminsdk-w04bv%40hackevents-prod.iam.gserviceaccount.com&amp;Expires=13569465600&amp;Signature=hCUhrbGN06LBYVoPSarQBkd3S4%2FoQeK5YrD8L2Y3IjWIUl4jjFC2H45wZM2zu87%2B0hcd2JlUo0OWYUnAZp5Zh4hw7ry%2FAxtuK8%2FtNjC7%2FjFQIPOdCY8WikPWd0aW%2B6i0%2BRnoI78%2FU%2BYBlFzmp0NhxCjFphFFVdnEyWl0TPc3sSBhencXmpkhlUOkJhCGyGrcyRn21LFGqqbPGzlCKoux3IXjSBje3JwGPX09VNm6QPkP%2FPfmj341HgG9cyvEKd0DFtu240vu%2FTviwlaZMjUh4vGVEssg6L5nEuDPgE0WdLiMahDvmWNnPSUmKZ9EcsFjimHMfioTJ7CP3UYa0SUqyQ%3D%3D" width="100%"/><!--include __firebaseStorageImageLoader--></div><div class="col-12 col-sm-7"><h3>Brigosha Hiring Hackathon</h3><hr/><p><i class="fas fa-map-marker-alt"></i>  coimbatore, India</p><p><i class="fas fa-calendar-check"></i> Starts 6/1/2
# ...

# %%
start=[i.text.split()[1] for i in soup_hack.select('div.row p:has(i.fa-calendar-check)')]
start
# Out:
# ['6/1/2019',
#  '6/1/2019',
#  '5/31/2019',
#  '6/8/2019',
#  '6/13/2019',
#  '6/15/2019',
#  '6/21/2019',
#  '6/27/2019',
#  '7/5/2019',
#  '1/31/2019']

# %%
title= [i.text.strip()for i in soup_hack.select('div.row h3')]
title
# Out:
# ['Brigosha Hiring Hackathon',
#  'Brigosha Hiring Hackathon',
#  '#apoHackathon',
#  'HackHunterdon',
#  'EU Datathon 2019',
#  'AIHacks',
#  'Financial Inclusion Hack - Banking the Unbanked',
#  'OSNA HACK 2019',
#  'Hackathon | Draper University',
#  'Galileo App Competition']

# %%
city=[i.text.strip().split(", ")[0] for i in soup_hack.select('div.row p:has(i.fa-map-marker-alt)')]
country= country=[i.text.strip().split(", ")[1] for i in soup_hack.select('div.row p:has(i.fa-map-marker-alt)')]
city
# Out:
# ['coimbatore',
#  'coimbatore',
#  'Düsseldorf',
#  'Flemington',
#  'Brussels',
#  'Los Angeles',
#  'Edinburgh',
#  'Osnabrück',
#  'San Mateo',
#  'Prague']

# %%
[i.text.strip().split() for i in soup_hack.select('div.row p:has(i.fa-map-marker-alt)')]
# Out:
# [['coimbatore,', 'India'],
#  ['coimbatore,', 'India'],
#  ['Düsseldorf,', 'Germany'],
#  ['Flemington,', 'United', 'States'],
#  ['Brussels,', 'Belgium'],
#  ['Los', 'Angeles,', 'United', 'States'],
#  ['Edinburgh,', 'United', 'Kingdom'],
#  ['Osnabrück,', 'Germany'],
#  ['San', 'Mateo,', 'United', 'States'],
#  ['Prague,', 'Czech', 'Republic']]

# %%
mylst=[elem.strip(',') for var in loc for elem in var]
print(mylst)
# Out:
# ['coimbatore', 'India', 'coimbatore', 'India', 'Düsseldorf', 'Germany', 'Flemington', 'United', 'States', 'Brussels', 'Belgium', 'Los', 'Angeles', 'United', 'States', 'Edinburgh', 'United', 'Kingdom', 'Osnabrück', 'Germany', 'San', 'Mateo', 'United', 'States', 'Prague', 'Czech', 'Republic']

# %%
[elem.strip(",").split() for var in loc for elem in var]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-184-579c97baae43> in <module>
# ----> 1 [elem.strip(",").split()[1] for var in loc for elem in var]
#
# <ipython-input-184-579c97baae43> in <listcomp>(.0)
# ----> 1 [elem.strip(",").split()[1] for var in loc for elem in var]
#
# IndexError: list index out of range

# %%
end=[i.text.split()[1] for i in soup_hack.select('div.row p:has(i.fa-calendar-times)')]
end
# Out:
# ['6/1/2019',
#  '6/1/2019',
#  '6/2/2019',
#  '6/9/2019',
#  '6/13/2019',
#  '6/16/2019',
#  '6/23/2019',
#  '6/28/2019',
#  '7/7/2019',
#  '9/30/2019']

# %%
event=pd.DataFrame([start,end,title,city,country]).T
event.columns=['start','end','title','city','country']
event
# Out:
#        start        end                                            title  \
# 0   6/1/2019   6/1/2019                        Brigosha Hiring Hackathon
# 1   6/1/2019   6/1/2019                        Brigosha Hiring Hackathon
# 2  5/31/2019   6/2/2019                                    #apoHackathon
# 3   6/8/2019   6/9/2019                                    HackHunterdon
# 4  6/13/2019  6/13/2019                                 EU Datathon 2019
# 5  6/15/2019  6/16/2019                                          AIHacks
# 6  6/21/2019  6/23/2019  Financial Inclusion Hack - Banking the Unbanked
# 7  6/27/2019  6/28/2019                                   OSNA HACK 2019
# 8   7/5/2019   7/7/2019                    Hackathon | Draper University
# 9  1/31/2019  9/30/2019                          Galileo App Competition
#
#           city         country
# 0   coimbatore           India
# 1   coimbatore           India
# 2   Düsseldorf         Germany
# 3   Flemington   United States
# ...

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/ActuML'

# %%
response=requests.get(url).content
soup_twitter=BeautifulSoup(response,'lxml') 
soup_twitter
tweet= soup_twitter.select('span:contains("Tweets") + span.ProfileNav-value')
''.join(tweet[0].text.strip().split())

tweet[0]['data-count']
# Out:
# '9240'

# %%
soup_twitter.select('span:contains("Tweets")+span')
# Out:
# [<span class="UserNameBreak"> </span>,
#  <span class="typeahead-social-context"></span>,
#  <span class="UserNameBreak"> </span>,
#  <span class="UserNameBreak"> </span>]

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/ActuML/?lang=en'

# %%
response=requests.get(url).content
soup_follower=BeautifulSoup(response,'lxml') 
soup_follower
follow= soup_follower.select('span:contains("Followers")+ span.ProfileNav-value')
follow
follow[0]['data-count']
# Out:
# '14798'

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
response=requests.get(url).content
soup_wiki=BeautifulSoup(response,'lxml') 
soup_wiki
wiki= soup_wiki.select('a>strong')
language=[i.text.strip()for i in soup_wiki.select('a>strong')]
language
# Out:
# ['English',
#  'Español',
#  '日本語',
#  'Deutsch',
#  'Русский',
#  'Français',
#  'Italiano',
#  '中文',
#  'Português',
#  'Polski']

# %%
wikil= soup_wiki.select('a>small')
wikil
article = [" ".join(i.text.split('+')[0].split()) for i in soup_wiki.select('a>small')]
article
# Out:
# ['5 860 000',
#  '1 523 000',
#  '1 152 000',
#  '2 305 000',
#  '1 545 000',
#  '2 107 000',
#  '1 530 000',
#  '1 058 000',
#  '1 006 000',
#  '1 338 000']

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
response=requests.get(url).content
soup_data=BeautifulSoup(response,'lxml') 
soup_data
data= soup_data.select('h2>a')
data
[i.text for i in soup_data.select('h2>a')]
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
response=requests.get(url).content
soup_speakers=BeautifulSoup(response,'lxml') 
soup_speakers
speaker= soup_speakers.select('table.wikitable')
speaker

rows=speaker[1].find_all('tr') 
rows=[row.text.strip().split('\n') for row in rows]
rows
cols=rows[0][0::2]
data=rows[1:11]
import pandas as pd
pd.DataFrame(data, columns=cols)[cols[1:3]]
# Out:
#                    Language Nativespeakersin millions2007 (2010)
# 0  Mandarin (entire branch)                            935 (955)
# 1                   Spanish                            390 (405)
# 2                   English                            365 (360)
# 3                  Hindi[b]                            295 (310)
# 4                    Arabic                            280 (295)
# 5                Portuguese                            205 (215)
# 6          Bengali (Bangla)                            200 (205)
# 7                   Russian                            160 (155)
# 8                  Japanese                            125 (125)
# 9                   Punjabi                             95 (100)

# %%
response=requests.get(url).content
soup_speakers=BeautifulSoup(response,'lxml') 
soup_speakers
speaker= soup_speakers.select('table.wikitable')
speaker

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
