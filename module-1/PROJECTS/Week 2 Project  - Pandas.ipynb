# %%
import pandas as pd
import os
os.chdir("../")
os.getcwd()
import numpy as np

# %%
sa=pd.read_csv('/Users/margueritevergne/Downloads/Sharkattack.csv', sep=',', engine= 'python')
sa
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
sa.shape
# Out:
# (5992, 24)

# %%
sa.columns #outputting name of columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sa.columns = ['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
       'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal', 'Time',
       'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
       'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
       'Unnamed: 23']
sa.columns #creating a list with corrected columns names and changing them in the DF
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sa.columns=[x.lower() for x in sa.columns] #columns header in lower case
sa.columns
# Out:
# Index(['case number', 'date', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex ', 'age', 'injury', 'fatal', 'time',
#        'species ', 'investigator or source', 'pdf', 'href formula', 'href',
#        'case number.1', 'case number.2', 'original order', 'unnamed: 22',
#        'unnamed: 23'],
#       dtype='object')

# %%
col_drops = ['original order','fatal','name','sex ','age','pdf','href','href formula','year','investigator or source','case number.1', 'case number.2']

sa=sa.drop(col_drops, axis=1) #dropping columns I judged non useful for shark attack analysis

# %% [markdown]
# # Missing Value

# %%
sa.columns[sa.isnull().sum()>0] #checking columns with empty value
# Out:
# Index(['country', 'area', 'location', 'activity', 'injury', 'time', 'species ',
#        'unnamed: 22', 'unnamed: 23'],
#       dtype='object')

# %%
null_cols=sa.isnull().sum() #create a column with empty values
null_cols
drop_percentage = round(null_cols[null_cols>0]/sa.shape[0]*100,2)
drop_cols = drop_percentage[drop_percentage>75].index #finding the columns that have more than 75% of Empty Value
drop_cols
# Out:
# Index(['unnamed: 22', 'unnamed: 23'], dtype='object')

# %%
sa[drop_cols].describe() #checking what's in the columns
# Out:
#          unnamed: 22      unnamed: 23
# count              1                2
# unique             1                2
# top     stopped here  change filename
# freq               1                1

# %%
sa = sa.drop(drop_cols, axis=1)
sa.shape #dropping the 2 most empty columns empty columns
# Out:
# (5992, 10)

# %%
drop_percentage #showing the non empty columns left
# Out:
# country         0.72
# area            6.71
# location        8.28
# activity        8.80
# injury          0.45
# time           53.62
# species        48.97
# unnamed: 22    99.98
# unnamed: 23    99.97
# dtype: float64

# %%
sa = sa.dropna(subset=['country','injury','activity','location', 'area']) #dropping rows with less than 10% empty values
sa.shape
# Out:
# (4874, 10)

# %%
#filling missing value with "unknown category"
sa = sa.fillna({
    'time':'np.nan',
    'species':'np.nan'
})

# %%
sa.shape #checking dropped rows
# Out:
# (4874, 10)

# %% [markdown]
# # Duplicates

# %%
sa.duplicated().sum() 
sa.drop_duplicates(keep= "first").shape #checking and dropping the duplicated rows
# Out:
# (4873, 10)

# %% [markdown]
# # Country

# %%
#removing special character in country and uppercase
sa.country=sa.country.str.replace(" / ", "")
sa.country=sa.country.str.replace("?", "")
sa['country'] = sa['country'].str.lower()
print(set(sa.country))
sa.shape
# Out:
# {'costa rica', 'taiwan', 'french polynesia', 'mozambique', 'indian ocean', 'south africa', 'norway', 'belize', 'federated states of micronesia', 'madagascar', 'guyana', 'new guinea', 'canada', 'greece', 'croatia', 'nigeria', 'tasman sea', 'saudi arabia', 'jamaica', 'ecuador', 'montenegro', 'somalia', 'spain', 'fiji', 'persian gulf', 'australia', 'cayman islands', 'new britain', 'yemen', 'united kingdom', 'tunisia', 'usa', 'nicaragua ', 'libya', 'kenya', 'sierra leone', 'caribbean sea', 'venezuela', 'philippines', 'slovenia', 'papua new guinea', 'cyprus', 'tonga', 'sudan', 'palau', 'israel', 'tanzania', 'turks & caicos', 'england', 'vietnam', 'cuba', 'portugal', 'south atlantic ocean', 'samoa', 'grenada', 'egyptisrael', 'china', 'pacific ocean ', 'lebanon', 'panama', 'okinawa', 'honduras', 'north pacific ocean', 'atlantic ocean', 'mauritius', 'yemen ', 'iran', 'antigua', 'mexico', 'indonesia', 'senegal', 'bahamas', 'nicaragua', 'uruguay', 'egypt', 'sri lanka', 'ceylon (sri lanka)', 'c
# ...

# %%
# check the right spelling in country and drop the wrong ones
lll=[]
list_countries=['afghanistan', 'aland islands', 'albania', 'algeria', 'american samoa', 'andorra', 'angola', 'anguilla', 'antarctica', 'antigua and barbuda', 'argentina', 'armenia', 'aruba', 'australia', 'austria', 'azerbaijan', 'bahamas (the)', 'bahrain', 'bangladesh', 'barbados', 'belarus', 'belgium', 'belize', 'benin', 'bermuda', 'bhutan', 'bolivia (plurinational state of)', 'bonaire, sint eustatius and saba', 'bosnia and herzegovina', 'botswana', 'bouvet island', 'brazil', 'british indian ocean territory (the)', 'brunei darussalam', 'bulgaria', 'burkina faso', 'burundi', 'cabo verde', 'cambodia', 'cameroon', 'canada', 'cayman islands (the)', 'central african republic (the)', 'chad', 'chile', 'china', 'christmas island', 'cocos (keeling) islands (the)', 'colombia', 'comoros (the)', 'congo (the democratic republic of the)', 'congo (the)', 'cook islands (the)', 'costa rica', "cote d'ivoire", 'croatia', 'cuba', 'curacao', 'cyprus', 'czechia', 'denmark', 'djibouti', 'dominica', 'dominican republic (the)', 'ecuador', 'egypt', 'el salvador', 'equatorial guinea', 'eritrea', 'estonia', 'ethiopia', 'falkland islands (the) [malvinas]', 'faroe islands (the)', 'fiji', 'finland', 'france', 'french guiana', 'french polynesia', 'french southern territories (the)', 'gabon', 'gambia (the)', 'georgia', 'germany', 'ghana', 'gibraltar', 'greece', 'greenland', 'grenada', 'guadeloupe', 'guam', 'guatemala', 'guernsey', 'guinea', 'guinea-bissau', 'guyana', 'haiti', 'heard island and mcdonald islands', 'holy see (the)', 'honduras', 'hong kong', 'hungary', 'iceland', 'india', 'indonesia', 'iran (islamic republic of)', 'iraq', 'ireland', 'isle of man', 'israel', 'italy', 'jamaica', 'japan', 'jersey', 'jordan', 'kazakhstan', 'kenya', 'kiribati', "korea (the democratic people's republic of)", 'korea (the republic of)', 'kuwait', 'kyrgyzstan', "lao people's democratic republic (the)", 'latvia', 'lebanon', 'lesotho', 'liberia', 'libya', 'liechtenstein', 'lithuania', 'luxembourg', 'macao', 'macedonia (the former yugoslav republic of)', 'madagascar', 'malawi', 'malaysia', 'maldives', 'mali', 'malta', 'marshall islands (the)', 'martinique', 'mauritania', 'mauritius', 'mayotte', 'mexico', 'micronesia (federated states of)', 'moldova (the republic of)', 'monaco', 'mongolia', 'montenegro', 'montserrat', 'morocco', 'mozambique', 'myanmar', 'namibia', 'nauru', 'nepal', 'netherlands (the)', 'new caledonia', 'new zealand', 'nicaragua', 'niger (the)', 'nigeria', 'niue', 'norfolk island', 'northern mariana islands (the)', 'norway', 'oman', 'pakistan', 'palau', 'palestine, state of', 'panama', 'papua new guinea', 'paraguay', 'peru', 'philippines (the)', 'pitcairn', 'poland', 'portugal', 'puerto rico', 'qatar', 'reunion', 'romania', 'russian federation (the)', 'rwanda', 'saint barthelemy', 'saint helena, ascension and tristan da cunha', 'saint kitts and nevis', 'saint lucia', 'saint martin (french part)', 'saint pierre and miquelon', 'saint vincent and the grenadines', 'samoa', 'san marino', 'sao tome and principe', 'saudi arabia', 'senegal', 'serbia', 'seychelles', 'sierra leone', 'singapore', 'sint maarten (dutch part)', 'slovakia', 'slovenia', 'solomon islands', 'somalia', 'south africa', 'south georgia and the south sandwich islands', 'south sudan', 'spain', 'sri lanka', 'sudan (the)', 'suriname', 'svalbard and jan mayen', 'swaziland', 'sweden', 'switzerland', 'syrian arab republic', 'taiwan (province of china)', 'tajikistan', 'tanzania, united republic of', 'thailand', 'timor-leste', 'togo', 'tokelau', 'tonga', 'trinidad and tobago', 'tunisia', 'turkey', 'turkmenistan', 'turks and caicos islands (the)', 'tuvalu', 'uganda', 'ukraine', 'united arab emirates (the)', 'united kingdom of great britain and northern ireland (the)', 'united states minor outlying islands (the)', 'usa', 'uruguay', 'uzbekistan', 'vanuatu', 'venezuela (bolivarian republic of)', 'viet nam', 'virgin islands (british)', 'virgin islands (u.s.)', 'wallis and futuna', 'western sahara*', 'yemen', 'zambia', 'zimbabwe']
for i in sa['country']:
    if i in list_countries:
        lll.append(i)
    else:
        lll.append(np.nan)
sa.country=lll
sa = sa.dropna(subset=['country'])

# %% [markdown]
# # Activity

# %%
#grouping the activity in the same category
sa.loc[sa['activity'].str.contains('fish', case=False), 'activity'] = 'Fishing'
sa.loc[sa['activity'].str.contains('bathing', case=False), 'activity'] = 'Swimming'
sa.loc[sa['activity'].str.contains('diving', case=False), 'activity'] = 'Diving'
sa.loc[sa['activity'].str.contains('surf', case=False), 'activity'] = 'Surfing'
sa.loc[sa['activity'].str.contains('snorkeling', case=False), 'activity'] = 'Swimming'
sa.loc[sa['activity'].str.contains('Treading Water', case=False), 'activity'] = 'Swimming'
sa.loc[sa['activity'].str.contains('board', case=False), 'activity'] = 'Surfing'
sa.loc[sa['activity'].str.contains('Standing', case=False), 'activity'] = 'Wading'
sa.loc[sa['activity'].str.contains('Walking', case=False), 'activity'] = 'Wading'
sa.loc[sa['activity'].str.contains('Playing', case=False), 'activity'] = 'Swimming'
sa.loc[sa['activity'].str.contains('swimming', case=False), 'activity'] = 'Swimming'
sa.loc[sa['activity'].str.contains('ski', case=False), 'activity'] = 'Swimming'
sa.loc[sa['activity'].str.contains('rowing', case=False), 'activity'] = 'Floating boat'
sa.loc[sa['activity'].str.contains('canoe', case=False), 'activity'] = 'Floating boat'
sa.loc[sa['activity'].str.contains('kayak', case=False), 'activity'] = 'Floating boat'
sa.loc[sa['activity'].str.contains('boat', case=False), 'activity'] = 'Boating'
sa.loc[sa['activity'].str.contains('Sailing', case=False), 'activity'] = 'Boating'

sa.shape

sa.activity.value.counts(normalize=True)*100
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-196-4ad24ce44a5d> in <module>
#      20 sa.shape
#      21
# ---> 22 sa.activity.value.counts(normalize=True)*100
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
#Dropping the rows that were not classified
mylist=['Fishing', 'Swimming', 'Diving','Surfing','Wading','Floating boat','Boating']
sa = sa[sa['activity'].isin(mylist)]
sa.shape
# Out:
# (4195, 10)

# %% [markdown]
# # Injuries

# %%
#grouping the injuries in the same category
sa.loc[sa['injury'].str.contains('no injury', case=False), 'injury'] = 'No Injury'
sa.loc[sa['injury'].str.contains('fatal', case=False), 'injury'] = 'Fatal'
sa.loc[sa['injury'].str.contains('lacerat', case=False), 'injury'] = 'Injury'
sa.loc[sa['injury'].str.contains('bit', case=False), 'injury'] = 'Injury'
sa.loc[sa['injury'].str.contains('severed', case=False), 'injury'] = 'Injury'
sa.loc[sa['injury'].str.contains('wound', case=False), 'injury'] = 'Injury'
sa.loc[sa['injury'].str.contains('minor', case=False), 'injury'] = 'Injury'
sa.loc[sa['injury'].str.contains('abrasion', case=False), 'injury'] = 'Injury'
sa.loc[sa['injury'].str.contains('punctures', case=False), 'injury'] = 'Injury'
sa.loc[sa['injury'].str.contains('broke', case=False), 'injury'] = 'Injury'
sa.loc[sa['injury'].str.contains('injured', case=False), 'injury'] = 'Injury'

# %%
#sa['injury'].value_counts(normalize=True) * 100

#Dropping the row that has not been assigned
inj=['No Injury', 'Injury', 'Fatal']
lst=[]

for i in sa['injury']:
    if i in inj:
        lst.append(i)
    else:
        lst.append(np.nan)
        
sa.injury=lst
sa = sa.dropna(subset=['injury'])

# %% [markdown]
# # Time

# %%
#grouping the time by category

sa.loc[sa['time'].str.contains('afternoon', case=False), 'time'] = 'Afternoon'
sa.loc[sa['time'].str.contains('Dusk', case=False), 'time'] = 'Afternoon'
sa.loc[sa['time'].str.contains('A.M.', case=False), 'time'] = 'Morning'
sa.loc[sa['time'].str.contains('Early morning', case=False), 'time'] = 'Morning'
sa.loc[sa['time'].str.contains('P.M.', case=False), 'time'] = 'Afternoon'
sa.loc[sa['time'].str.contains('P.M.', case=False), 'time'] = 'Afternoon'
sa.loc[sa['time'].str.contains('P.M.', case=False), 'time'] = 'Afternoon'
sa.loc[sa['time'].str.startswith('00'), 'time'] = 'Night'
sa.loc[sa['time'].str.startswith('01'), 'time'] = 'Night'
sa.loc[sa['time'].str.startswith('02'), 'time'] = 'Night'
sa.loc[sa['time'].str.startswith('03'), 'time'] = 'Night'
sa.loc[sa['time'].str.startswith('04'), 'time'] = 'Night'
sa.loc[sa['time'].str.startswith('05'), 'time'] = 'Night'
sa.loc[sa['time'].str.startswith('06'), 'time'] = 'Morning'
sa.loc[sa['time'].str.startswith('07'), 'time'] = 'Morning'
sa.loc[sa['time'].str.startswith('08'), 'time'] = 'Morning'
sa.loc[sa['time'].str.startswith('09'), 'time'] = 'Morning' 
sa.loc[sa['time'].str.startswith('10'), 'time'] = 'Morning'
sa.loc[sa['time'].str.startswith('11'), 'time'] = 'Morning'
sa.loc[sa['time'].str.startswith('12'), 'time'] = 'Afternoon'
sa.loc[sa['time'].str.startswith('13'), 'time'] = 'Afternoon'
sa.loc[sa['time'].str.startswith('14'), 'time'] = 'Afternoon'
sa.loc[sa['time'].str.startswith('15'), 'time'] = 'Afternoon'
sa.loc[sa['time'].str.startswith('16'), 'time'] = 'Afternoon'
sa.loc[sa['time'].str.startswith('17'), 'time'] = 'Evening'
sa.loc[sa['time'].str.startswith('18'), 'time'] = 'Evening'
sa.loc[sa['time'].str.startswith('19'), 'time'] = 'Evening'
sa.loc[sa['time'].str.startswith('20'), 'time'] = 'Evening'
sa.loc[sa['time'].str.startswith('21'), 'time'] = 'Night'
sa.loc[sa['time'].str.startswith('22'), 'time'] = 'Night'
sa.loc[sa['time'].str.startswith('23'), 'time'] = 'Night'
sa.loc[sa['time'].str.startswith('24'), 'time'] = 'Night'

#Dropping columns that were not assigned in a group

time_day=['Morning', 'Afternoon','Evening','Night']
list=[]

for i in sa['time']:
    if i in time_day:
        list.append(i)
    else:
        list.append(np.nan)
        
sa.time=list
sa = sa.dropna(subset=['time'])
 
sa.shape
# Out:
# (2131, 10)

# %%
sa
# Out:
#        case number         date        type        country               area  \
# 0     2016.09.18.c    18-Sep-16  Unprovoked            usa            Florida
# 1     2016.09.18.b    18-Sep-16  Unprovoked            usa            Florida
# 2     2016.09.18.a    18-Sep-16  Unprovoked            usa            Florida
# 6       2016.09.11    11-Sep-16  Unprovoked            usa            Florida
# 7       2016.09.07    07-Sep-16  Unprovoked            usa             Hawaii
# 8       2016.09.06    06-Sep-16  Unprovoked  new caledonia     North Province
# 9     2016.09.05.b    05-Sep-16  Unprovoked            usa     South Carolina
# 10    2016.09.05.a    05-Sep-16  Unprovoked      australia  Western Australia
# 13    2016.08.29.b    29-Aug-16  Unprovoked            usa            Florida
# 14    2016.08.29.a    29-Aug-16  Unprovoked            usa            Florida
# 16      2016.08.25    25-Aug-16  Unprovoked            usa            Florida
# ...

# %%
sa.to_csv('/Users/margueritevergne/data-labs/module-1/PROJECTS/shark_attack.csv')
